# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Dataset_w6.xlsx')

# %%
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %% [markdown]
# # No of Countries

# %%
country=data['country'].count()
print('Number of countries:',country)
# Out:
# Number of countries: 196

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(10,5))
x = data['Region']
y = data['Population in thousands (2017)']
plt.xlabel('Region')
plt.ylabel('Population in thousands')
plt.bar(x,y)
plt.xticks(rotation=90);

# %% [markdown]
# The population of EasternAsia region is higher than others.Also the population of Polynesia and Micronesia is significantly
# small compared to others.

# %%
plt.figure(figsize=(10,5))
x = data['Region']
y = data['GDP per capita (current US$)']
plt.xlabel('Region')
plt.ylabel('GDP per capita (current US$)')
plt.bar(x,y,color= 'red')
plt.xticks(rotation=90);

# %% [markdown]
# The highest GDP per capita is for WesternEurope and the lowest is for WesternAfrica.

# %% [markdown]
# # No of Countries with respect to region

# %%
data.groupby('Region')["country"].count()
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %% [markdown]
# # Average on GDP and Intenational trade

# %%
plt.figure(figsize=(10,5))
data1=data.groupby('Region')['GDP per capita (current US$)'].mean().plot(kind='bar')
plt.title("Average GDP Per Capita")
plt.show()

# %% [markdown]
# On average NorthAmerica has the highest GDP per capita.

# %%
plt.figure(figsize=(10,5))
data1=data.groupby('Region')['International trade: Imports (million US$)'].mean().plot(kind='bar')
plt.title("Average Inernational trade:Imports")
plt.show()

# %% [markdown]
# NorthAmerica comes top on average International trade: Imports

# %% [markdown]
# # More Consistent Region with respect to GDP

# %%
data2=data.groupby('Region')['GDP per capita (current US$)'].std()
data2
# Out:
# Region
# Caribbean            14579.371326
# CentralAmerica        4180.440883
# CentralAsia           4152.215490
# EasternAfrica         3716.131770
# EasternAsia          27485.120923
# EasternEurope         5415.488739
# Melanesia            13855.842686
# Micronesia            4820.669694
# MiddleAfrica          5274.846281
# NorthernAfrica         974.706575
# NorthernAmerica      25749.619445
# NorthernEurope       20671.030185
# Oceania               9233.329638
# Polynesia             6956.250286
# South-easternAsia    16311.810656
# SouthAmerica          4273.707394
# SouthernAfrica        2177.551120
# SouthernAsia          2855.708179
# SouthernEurope        9541.703216
# WesternAfrica          815.095399
# WesternAsia          18812.151459
# WesternEurope        24770.467728
# Name: GDP per capita (current US$), dtype: float64

# %%
data2.nsmallest(1)
# Out:
# Region
# WesternAfrica    815.095399
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# WesternAfrica has less standard deviation.Hence it is more consistent with respect to GDP
