# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('diabetes_model.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
data1=data.head()

# %%
data1
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            5       77             82             41       42  35.8
# 1            9      122             56              0        0  33.3
# 2            0      113             76              0        0  33.3
# 3            1      139             62             41      480  40.7
# 4           10      161             68             23      132  25.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.156   35        0
# 1                     1.114   33        1
# 2                     0.278   23        1
# 3                     0.536   21        0
# 4                     0.326   47        1

# %%
data.isna().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %% [markdown]
# # Countplot of Outcome

# %%
sns.countplot(data['Outcome'])
# Out:
# C:\Users\Rajasree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %% [markdown]
# # Effect of Age on Outcome

# %%
sns.boxplot(x='Outcome',y='Age',data=data)
plt.title('Age vs Outcome')
# Out:
# Text(0.5, 1.0, 'Age vs Outcome')

# %% [markdown]
# As age increases chance of getting diabetes also increases

# %% [markdown]
# # Chance of getting diabetes

# %%
sns.boxplot(x='Outcome',y='DiabetesPedigreeFunction',data=data)
plt.title('Outcome vs DiabetesPedigreeFunction ')
# Out:
# Text(0.5, 1.0, 'Outcome vs DiabetesPedigreeFunction ')

# %% [markdown]
# # Relationship with Insulin and Glucose

# %%
sns.scatterplot(data['Insulin'],data['Glucose'],hue=data['Outcome'])
plt.title('Plot of Insulin vs Glucose',fontsize=16)
plt.figure(figsize=(8,8))
plt.show()
# Out:
# C:\Users\Rajasree\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Heatmap on Correlation

# %%
sns.heatmap(data.corr(),annot=True)
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  [Text(0.5, 0, 'Pregnancies'),
#   Text(1.5, 0, 'Glucose'),
#   Text(2.5, 0, 'BloodPressure'),
#   Text(3.5, 0, 'SkinThickness'),
#   Text(4.5, 0, 'Insulin'),
#   Text(5.5, 0, 'BMI'),
#   Text(6.5, 0, 'DiabetesPedigreeFunction'),
#   Text(7.5, 0, 'Age'),
#   Text(8.5, 0, 'Outcome')])
